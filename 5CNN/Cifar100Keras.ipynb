# %% [markdown]
# <a href="https://colab.research.google.com/github/aquapathos/BasicAI/blob/master/5CNN/Cifar100Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='red'>【参照のみ・編集不可】
#
# *   まずこのファイルを複製して実験を始めてください。(ファイルメニューの「ドライブにコピーを保存」)
# *   課題は下の方に書いてあります。</font>

# %% [markdown]
# # CIFAR-100 画像データを用いた機械学習と画像認識の実験
#
# # はじめに
#
# ![cifar100)](https://user-images.githubusercontent.com/5820803/93660941-d8ee0900-fa8e-11ea-9d81-4c17f52c128e.png)
#
# 　　　　　　図１　CIAR-100 画像の例
#
#  CIFAR-100は画像認識の研究用画像データセットです。詳しくは[こちら](https://www.atmarkit.co.jp/ait/articles/2006/15/news036.html)
#
# - 5万枚の訓練データ用（画像とラベル）   (train)
# - 1万枚のテストデータ用（画像とラベル） (test)
#
# 合計6万枚で構成されています。
#
#   これらの画像は動物や乗り物など100カテゴリの被写体のどれかが写った写真です.
#  それぞれの被写体の画像は同じ枚数存在します。つまり、訓練データは1種類500枚ずつ、テストデータは100枚ずつとなっています。

# %% [markdown]
# # １．準備
#
# まず説明を読みながら「課題」の前まで一通り実行し、実験内容を理解してください。
#
# **GPU**が使えるかどうかで実行時間が大きく変わります。
#
# （説明を読んで理解する時間を除いて）すべてのプログラムの実行に要する時間は次のとおりです。
# - GPUが使える場合　約５分
# - CPUのみで実行した場合　約15分
#
# 「**ランタイム**」メニューの「**ランタイムのタイプを変更**」でハードウェアアクセラレータとして**GPU**を選べばGPUが使えます。
#
# ただし、混雑している時間帯などには、設定でGPUを選んでも、GPUが割り当てられないことがあります。
#
# データセットの読み込みや学習に時間がかかります。その間に次の説明を読み進めるようにしてください。
#
# ## 1.1　ライブラリのインポート、データの読み込み、サポート関数の定義
# - ライブラリの読み込み
# - データセットの読み込み
# - 表示用関数の定義
#
# #### <font color='red'>　実行方法</font>
# 各セルの左上の ▶ マークをクリックするか、実行したいセルをクリックして**Shift+Enter** でそのセル内のプログラムが実行されます。
#
# インタラクティブに実行を進めますが、あくまでも python プログラムなので、基本的に上から順に実行する必要があります。
#
# 次のセルでは、実行に必要なライブラリの読み込みを行います。最初に必ず1度実行する必要があります。2度実行する必要はありません。
#
# #### <font color='red'>　行き詰まったら</font>
#
# - 最初からやり直したい場合は、「ランタイム」メニューの「ランタイムを再起動」を実行してください。そうすれば初期化されます。（ただし、書き換えたコードはもとには戻りません）
# - コードの書き換えで間違ったりしてわからなくなった場合は、もう一度、https://colab.research.google.com/drive/1RHS8-06B-Yl4F2-WMY_OnV7TWt5clXt6?usp=sharing　を開いて新たなコピーを保存し、やり直してください。

# %%
# !pip -q install japanize-matplotlib
# !wget -q https://github.com/iciromaco/MLLesson/raw/master/ML08%20%E4%B8%80%E8%88%AC%E7%89%A9%E4%BD%93%E8%AA%8D%E8%AD%98/cifar-100/CifarLib.py
from sklearn import svm, metrics
# from sklearn.model_selection import StratifiedShuffleSplit

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,Dense, Activation
from tensorflow.keras.layers import MaxPool2D #,AveragePooling2D
from tensorflow.keras.optimizers import Adam #, SGD
from tensorflow.keras.layers import Dropout, Flatten, GlobalAveragePooling2D,BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger,TensorBoard
from tensorflow.keras.utils import plot_model, to_categorical
from keras.callbacks import TensorBoard

from keras.datasets import cifar100
from tensorflow import keras
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import japanize_matplotlib
from PIL import Image
import math
from IPython.display import display_png
from IPython.display import Image as IPImage

from CifarLib import * # 独自ライブラリ

SIZE = 32
CLASSES = 3 # カテゴリ数
DATASIZE = SIZE *  SIZE * 3

# データセットの読み込み
(X_train, y_train),(X_test, y_test) = cifar100.load_data()
# Out:
#      |████████████████████████████████| 4.1 MB 4.2 MB/s
#   Building wheel for japanize-matplotlib (setup.py) ... done
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step
# 169017344/169001437 [==============================] - 11s 0us/step

# %% [markdown]
# # 1.2 データの確認

# %%
# テストデータの224番から100枚表示
showimages(X_train,224)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FF1DFE1DFD0>

# %% [markdown]
# #### The CIFAR-100 dataset
#
# 最初のセルの実行でデータセットの読み込みを行っており、配列変数 **(X_train,y_train)、(X_test,y_test)** にデータが格納されています。
#
# **X_train[n]**と**X_test[n]**が、それぞれn番目の訓練用画像とn番目のテスト用画像で、**y_train[n]**、**y_test[n]**にその画像の正解番号（０～９９）が入っています。
#
# CIFAR100 の100のカテゴリーを次の表に示します。
#
# |大分類|カテゴリー|
# |:--:|:--|
# |花|ラン,ヒマワリ,チューリップ,バラ,ポピー|
# |キッチン用具|ボトル,ボウル,缶,カップ,プレート|
# |果物・野菜|リンゴ,オレンジ,ナシ,ピーマン,キノコ|
# |家電|時計,キーボード,ランプ,電話,テレビ|
# |家具|ベッド,椅子,ソファー,タンス,テーブル|
# |大型肉食獣|クマ,ヒョウ,ライオン,トラ,オオカミ|
# |草食・雑食獣|ラクダ,ウシ,チンパンジー,ゾウ,カンガルー|
# |中型哺乳類|キツネ,ヤマアラシ,フクロネズミ,スカンク,ラクーン|
# |小型哺乳類|ハムスター,マウス,トガリネズミ,ウサギ,リス|
# |昆虫|蜂,甲虫,蝶,いも虫,ゴキブリ|
# |爬虫類|クロコダイル,恐竜,トカゲ,カメ,ヘビ|
# |水棲哺乳類|ビーバー,イルカ,カワウソ,クジラ,アザラシ|
# |魚類|観賞魚,ヒラメ,エイ,エイ,サメ,マス|
# |構造物|橋,城,超高層ビル,家,道路|
# |無脊椎動物|クモ,カタツムリ,カニ,ロブスター,ミミズ|
# |シーン|雲,森林,山,平原,海|
# |人間|赤ちゃん,男の子,女性,女の子,男性|
# |樹木|カエデ,カシ,マツ,ヤナギ,ヤシ|
# |車両１|自転車,バス,列車,ピックアップトラック,オートバイ|
# |車両２|芝刈り機,ロケット,路面電車,タンク,トラクター|

# %% [markdown]
# 画像を確認するための関数を用意しました。次のコードで訓練データ中のイルカの画像が100枚表示されます。250は250番目のイルカ画像から始めて100枚という意味です。

# %%
# 訓練データ（X_train）からイルカを抽出して100枚表示
showimages(getCatJ(X_train,y_train,'イルカ'),250)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FF1DFD95D50>

# %% [markdown]
# # ２．実験用データの選択
#
# CIFAR-100は一般画像認識用としてはもっともサイズの小さい部類のデータセットですが、それでも機械学習はとても時間がかかるので、全部を対象に学習させると何時間もかかってしまいます。
#
# そこで、この実験では、１００のカテゴリから３カテゴリだけを選び、訓練用から3カテゴリそれぞれ１００枚を抜き出して学習させ、テスト用の１００枚で結果を評価することにします。
#
# 次のセルを実行すると、
# - cat1 = 'オレンジ'   （→ dset1 に格納）
# - cat2 = 'リンゴ'   　（→ dset2 に格納）
# - cat3 ='ピーマン'    （→ dset3 に格納）
#
# のデータが抽出されます。
#
# 最初はこの３種で一通り実験を行って要領を理解してください。

# %%
cat1,cat2,cat3 = 'オレンジ','リンゴ','ピーマン'
dset1 = getCatJ(X_train,y_train,cat1)[0:100] #  オレンジの画像100枚の配列 訓練用
dset2 = getCatJ(X_train,y_train,cat2)[0:100] #  リンゴの画像100枚の配列 訓練用
dset3 = getCatJ(X_train,y_train,cat3)[0:100] #  ピーマンの画像100枚の配列 訓練用
tset1 = getCatJ(X_test,y_test,cat1) #  オレンジの画像100枚の配列 テスト用
tset2 = getCatJ(X_test,y_test,cat2) #  リンゴの画像100枚の配列 テスト用
tset3 = getCatJ(X_test,y_test,cat3) #  ピーマンの画像100枚の配列 テスト用
Xtrain = (np.r_[dset1,dset2,dset3].astype('float32'))/255
ytrain = np.array([0]*100+[1]*100+[2]*100).astype('float32') 
Xtest = (np.r_[tset1,tset2,tset3].astype('float32'))/255
ytest = ytrain.copy()
# 訓練データをシャッフルする
p = np.random.permutation(len(Xtrain))    # ランダムなインデックス順の取得
Xtrain, ytrain = Xtrain[p], ytrain[p]

# %% [markdown]
# # 各カテゴリの画像の確認

# %%
showimages(dset1)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FF1DFD918D0>

# %%
showimages(dset2)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FF1DFDB61D0>

# %%
showimages(dset3)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FF1DFDBD210>

# %% [markdown]
# # ３．学習実験
#
# データの準備が整ったので、学習のフェーズに進みましょう。

# %% [markdown]
# # 3.1 SVM　サポートベクターマシン
# **SVM（サポートベクタマシン）**は深層学習が登場するまでは、最強とされていた統計的機械学習法です。
# まず、SVMでどの程度認識率が得られるかを試しておきます。
#
# SVMには識別面が超平面に限定される**線形SVM**と、曲面を識別面とすることのできる**非線形SVM**があります。両方試してみましょう。

# %%
# %%time
clfL = svm.LinearSVC(max_iter=10000)
clf = svm.SVC(max_iter=-1)
XtrainFlat = Xtrain.reshape(len(Xtrain),DATASIZE)
XtestFlat = Xtest.reshape(len(Xtest),DATASIZE)
clfL.fit(XtrainFlat, ytrain)
clf.fit(XtrainFlat, ytrain)
print("線形SVM") #
print("　訓練用画像での正答率{:5.4f}%".format(clfL.score(XtrainFlat, ytrain)*100)) #
print("　テスト用画像での正答率{:5.4f}".format(clfL.score(XtestFlat, ytest)*100)) # 
print("非線形SVM") #
print("　訓練用画像での正答率{:5.4f}%".format(clf.score(XtrainFlat, ytrain)*100)) # 
print("　テスト用画像での正答率{:5.4f}".format(clf.score(XtestFlat, ytest)*100)) #
# Out:
# 線形SVM
# 　訓練用画像での正答率100.0000%
# 　テスト用画像での正答率49.6667
# 非線形SVM
# 　訓練用画像での正答率89.0000%
# 　テスト用画像での正答率63.0000
# CPU times: user 23.1 s, sys: 98.6 ms, total: 23.2 s
# Wall time: 23.6 s

# %% [markdown]
# **線形SVM**は、訓練用画像は完璧に識別できる代わりに,'オレンジ','リンゴ','ピーマン'のテスト用画像では正答率約50％、２つに１つ間違います。しかし、３択問題なのでランダムに答えを選んだ場合の理論的な正答率33％です。それよりは高い値なので、学習の効果があると言えます。
#
# **非線形SVM**は訓練用画像でも10％ほど間違ってしまいますが、テスト画像での正答率が63％ですからも、３つに１つぐらいしか間違わないという結果となります。
#
# この結果はデフォルト設定での結果であり、チューニングしてやればすればもう少し改善できるでしょう。
#
# なお、正解率は選んだカテゴリによって大きく変化します。

# %% [markdown]
# # 3.2 model1 ３層バックプロパゲーションネット
#
# 入力層、中間層、出力層、各１層ずつからなる、もっとも基本的なニューラルネットワークを**モデル１**として、どの程度のパフォーマンスが得られるか試してみます。

# %% [markdown]
# ### モデルの構造定義

# %% [markdown]
# python用の機械学習ライブラリは何種類もありますが、このプログラムでは、Google が公開している **Tensorflow-Keras**というライブラリを利用しています。Keras で中間層１の全結合ニューラルネットワークの構造は次のように記述できます。
#
# ```
# # ３層バックプロパゲーションネットのモデル定義
# Sequential([
#       Dense(64,activation='relu',input_shape=(DATASIZE,)), # 中間層は全結合で64ノード
#       Dense(CLASSES, activation='softmax')]) # 出力層は全結合で３ノード、softmax出力
# ```
#
# **Sequential** 単純に層を並べただけの単純な階層型ネットワークであることを意味します。
# **Dense()** 全結合層
# **input_shape** 入力データの構造。上のプログラムでは、画素データすべてがフラットに並んだ構造を指定しています。
#
# <font color="darkgreen">深層学習のプログラムには、この構造定義に加えて様々なハイパーパラメータの設定が必要です。１から全部設定して学習プログラムを記述すると複雑でわかりにくくなるので、この実験では最小限の記述だけで実験を進められるように　NNModel というクラスを用意しました。興味のある人は、CifarLib.pyを解読してください</font>
#
# 学習器 model1 のインスタンスを作ります。

# %%
# ３層バックプロパゲーションネットのモデル定義
NN1 = Sequential([
      Dense(64,activation='relu',input_shape=(DATASIZE,)), # 中間層は全結合で64ノード
      Dense(CLASSES, activation='softmax')]) # 出力層は全結合で３ノード、softmax出力

CATLIST=[cat1,cat2,cat3] # カテゴリのリスト　（3カテゴリ限定）
DSET = (Xtrain,ytrain,Xtest,ytest) # データセット
model1 = NNModel(model=NN1,catlist=CATLIST,dset=DSET,type='MLP') # 学習モデルのインスタンス生成
model1.summary() # モデルの概要表示
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                196672
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 196,867
# Trainable params: 196,867
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Total params の値は、このモデルに含まれるパラメータ数、すなわち重み変数の数です。こんな単純なモデルでも、約20万個のパラメータあります。その値を調整することが、ニューラルネットワークの学習なのです。
#
# 講義では説明を簡単にするために２次元か３次元で図示していますが、このモデルの場合だと約20万次元の最適化問題を解かないといけないということです。
#
# 次の関数で、層構造の概要が示されます。

# %%
# ネットワーク構造の概観
model1.plot('model1.png')
display_png(IPImage('model1.png'))

# %% [markdown]
# ### 学習
# model1 に学習させてみましょう。

# %%
# 学習
model1.learn(verbose=1,epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 4ms/step - loss: 1.1030 - accuracy: 0.3833
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0246 - accuracy: 0.4667
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9815 - accuracy: 0.5100
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9727 - accuracy: 0.4733
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9411 - accuracy: 0.5267
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9279 - accuracy: 0.5767
# Epoch 7/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8881 - accuracy: 0.6167
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8849 - accuracy: 0.5700
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8717 - accuracy: 0.6067
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8570 - accuracy: 0.6300
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8353 - accuracy: 0.6333
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8300 - accuracy: 0.6533
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8143 - accuracy: 0.6433
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8229 - accuracy: 0.6633
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7867 - accuracy: 0.6833
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7795 - accuracy: 0.6733
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7622 - accuracy: 0.6867
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7517 - accuracy: 0.6967
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7490 - accuracy: 0.7300
# Epoch 20/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7363 - accuracy: 0.7100
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7322 - accuracy: 0.7233
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7151 - accuracy: 0.7267
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7106 - accuracy: 0.7467
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7023 - accuracy: 0.7533
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7099 - accuracy: 0.7167
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7035 - accuracy: 0.7100
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6828 - accuracy: 0.7533
# Epoch 28/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6730 - accuracy: 0.7700
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6680 - accuracy: 0.7600
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6674 - accuracy: 0.7767
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6742 - accuracy: 0.7467
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6479 - accuracy: 0.7700
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6411 - accuracy: 0.8000
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6298 - accuracy: 0.7833
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6510 - accuracy: 0.7500
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6409 - accuracy: 0.7700
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6264 - accuracy: 0.7833
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6279 - accuracy: 0.7800
# Epoch 39/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6021 - accuracy: 0.8100
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5890 - accuracy: 0.8200
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5900 - accuracy: 0.8167
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6142 - accuracy: 0.7667
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5859 - accuracy: 0.7933
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6096 - accuracy: 0.7833
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5750 - accuracy: 0.8167
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5645 - accuracy: 0.8033
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5676 - accuracy: 0.8067
# Epoch 48/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5375 - accuracy: 0.8633
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5499 - accuracy: 0.8167
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5400 - accuracy: 0.8467
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.8633
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.8633
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.8567
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5088 - accuracy: 0.8700
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5016 - accuracy: 0.8700
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5048 - accuracy: 0.8567
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5143 - accuracy: 0.8333
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4897 - accuracy: 0.8667
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4909 - accuracy: 0.8833
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4829 - accuracy: 0.8700
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4676 - accuracy: 0.8800
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.8900
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4635 - accuracy: 0.8900
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.8867
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4568 - accuracy: 0.8800
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.8667
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.8800
# Epoch 68/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.9000
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.8967
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4340 - accuracy: 0.9000
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4299 - accuracy: 0.8867
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4214 - accuracy: 0.9033
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.9033
# Epoch 74/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4218 - accuracy: 0.9100
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4095 - accuracy: 0.9200
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.9133
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4138 - accuracy: 0.9000
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4051 - accuracy: 0.8967
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8933
# Epoch 80/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.9267
# Epoch 81/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3824 - accuracy: 0.9400
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3783 - accuracy: 0.9333
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3851 - accuracy: 0.9200
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3812 - accuracy: 0.9267
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.9300
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3744 - accuracy: 0.9133
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3614 - accuracy: 0.9233
# Epoch 88/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3668 - accuracy: 0.9100
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3719 - accuracy: 0.9200
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3555 - accuracy: 0.9200
# Epoch 91/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3572 - accuracy: 0.9367
# Epoch 92/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3542 - accuracy: 0.9233
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3491 - accuracy: 0.9200
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3485 - accuracy: 0.9300
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3484 - accuracy: 0.9200
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3569 - accuracy: 0.9167
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3409 - accuracy: 0.9267
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3315 - accuracy: 0.9433
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3282 - accuracy: 0.9400
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3193 - accuracy: 0.9500

# %% [markdown]
# - **verbose** 途中経過の表示の程度。0とすると経過を表示しなくなる。
# - **epochs** 学習回数。 100 なら全データを使った重み調整を100回繰り返すことを意味する。
#
# なお、誤差が減らなくなった場合は指定した回数に達していなくても繰り返しを打ち切ります。

# %% [markdown]
# <font color='red'>（注意）learn を２度実行すると、追加学習になります。最初からやり直したい場合は、「学習器 model1 のインスタンスを作ります。」のセルからやり直してください。</font>

# %% [markdown]
# ### 結果の意味
# - <font color='red'> **loss**</font> : 教師データと結果の差の誤差
# - <font color='red'> **accuracy**</font> : 正解率
#
# 学習中に出力されている誤差と正解率は訓練データに対するものです。通常は誤差は０、正解率は１（100%)に近づいていきます。
#
# 学習過程をグラフ化しておきましょう。

# %%
# 学習過程のグラフ化
model1.hplot()

# %% [markdown]
# ## モデルの評価

# %%
# モデルの評価
model1.recognitionResult()
# Out:
# 訓練データの認識率
# 誤認識 18/300
# 　正答率= 94.0　誤り率＝  6.0 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン    正答率
# 正解カテゴリ
# オレンジ     100    0     0  100.0
# リンゴ        6   88     6   88.0
# ピーマン       5    1    94   94.0
# テストデータの認識率
# 誤認識 122/300
# 　正答率= 59.3　誤り率＝ 40.7 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン   正答率
# 正解カテゴリ
# オレンジ      74   12    14  74.0
# リンゴ       16   60    24  60.0
# ピーマン      37   19    44  44.0

# %% [markdown]
# モデル１は訓練用データはほぼ正解するようになりますが、テストデータの正答率は６割程度となるはずです。
# （ランダム性があるので、性能は前後します。また、カテゴリの組み合わせが変われば結果は大きく変化します）
#
# この３カテゴリでは、ピーマンの正答率がリンゴ、オレンジよりかなり低くなります。

# %%
# 訓練データで間違った画像（最大１６まで表示）
model1.showErrorImages(mode = 'train')
# Out:
# 下に示す例を含め 18 枚

# %%
# テストデータで間違った画像の例（最大１６まで表示）
model1.showErrorImages(mode = 'test')
# Out:
# 下に示す例を含め 122 枚

# %% [markdown]
# # 3.3  model2　典型的なCNN
#
# 典型的な畳み込みニューラルネットワークを試してみましょう。
#
# 次のような層構造の深層ネットワークを構成します。
#
# 1. ３ｘ３畳み込み　64チャネル 　 -> (32x32)x64チャネル
# 2. ３ｘ３畳み込み　64チャネル 　 -> (32x32)x64チャネル
# 3. max pooling 2x2 -> (16x16)x64チャネル
# 4. ３ｘ３畳み込み　64チャネル　 -> (16x16)x64チャネル
# 5. ３ｘ３畳み込み　32チャネル　 -> (16x16)x64チャネル
# 6. max pooling 2x2 -> (8x8)x64チャネル
# 7. BachNormalization
# 8. 256ノード全結合 -> 256ノード
# 9. Dropout
# 9. 64ノード全結合 -> ノード
# 10. 3ノード全結合 -> 3ノード
#
# 畳み込み層と出力層以外の全結合層の活性化関数としては ReLU関数を用いる。出力層は  softmax 関数を通して出力。

# %% [markdown]
# ## モデル定義

# %%
# Model 2
NN2 = Sequential([
    Conv2D(64, kernel_size=(3, 3),input_shape=(SIZE, SIZE,3), activation='relu',padding='same'),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(CLASSES, activation='softmax')])

# CATLIST=[cat1,cat2,cat3] # カテゴリのリスト　（3カテゴリ限定）
# DSET = (Xtrain,ytrain,Xtest,ytest) # データセット
model2 = NNModel(model=NN2,catlist=CATLIST,dset=DSET,type='CNN') # 学習モデルのインスタンス生成
model2.summary() # モデルの概要表示
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 16, 16, 64)       256
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense_2 (Dense)             (None, 128)               524416
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 645,955
# Trainable params: 645,699
# Non-trainable params: 256
# _________________________________________________________________

# %%
# ネットワーク構造の概観
model2.plot('model2.png')
display_png(IPImage('model2.png'))

# %%
# 学習
model2.learn(verbose=1,epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 8s 31ms/step - loss: 1.3537 - accuracy: 0.3767
# Epoch 2/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9259 - accuracy: 0.5800
# Epoch 3/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.8633 - accuracy: 0.6267
# Epoch 4/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6752 - accuracy: 0.7200
# Epoch 5/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6531 - accuracy: 0.7600
# Epoch 6/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5794 - accuracy: 0.7633
# Epoch 7/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5133 - accuracy: 0.7967
# Epoch 8/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4631 - accuracy: 0.8200
# Epoch 9/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4212 - accuracy: 0.8567
# Epoch 10/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3827 - accuracy: 0.8533
# Epoch 11/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3671 - accuracy: 0.8900
# Epoch 12/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2963 - accuracy: 0.9000
# Epoch 13/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2795 - accuracy: 0.9167
# Epoch 14/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2486 - accuracy: 0.9167
# Epoch 15/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2173 - accuracy: 0.9433
# Epoch 16/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2329 - accuracy: 0.9167
# Epoch 17/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1825 - accuracy: 0.9400
# Epoch 18/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1689 - accuracy: 0.9600
# Epoch 19/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1532 - accuracy: 0.9633
# Epoch 20/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1415 - accuracy: 0.9633
# Epoch 21/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1251 - accuracy: 0.9667
# Epoch 22/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1226 - accuracy: 0.9700
# Epoch 23/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1329 - accuracy: 0.9700
# Epoch 24/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1302 - accuracy: 0.9567
# Epoch 25/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1105 - accuracy: 0.9633
# Epoch 26/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1060 - accuracy: 0.9767
# Epoch 27/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1028 - accuracy: 0.9800
# Epoch 28/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0934 - accuracy: 0.9867
# Epoch 29/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0584 - accuracy: 0.9900
# Epoch 30/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9900
# Epoch 31/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0698 - accuracy: 0.9833
# Epoch 32/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0872 - accuracy: 0.9733
# Epoch 33/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0714 - accuracy: 0.9900
# Epoch 34/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0726 - accuracy: 0.9833

# %%
# 学習過程のグラフ化
model2.hplot()

# %%
# モデルの評価
model2.recognitionResult()
# Out:
# 訓練データの認識率
# 誤認識 197/300
# 　正答率= 34.3　誤り率＝ 65.7 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン    正答率
# 正解カテゴリ
# オレンジ       0  100     0    0.0
# リンゴ        0  100     0  100.0
# ピーマン       0   97     3    3.0
# テストデータの認識率
# 誤認識 200/300
# 　正答率= 33.3　誤り率＝ 66.7 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン    正答率
# 正解カテゴリ
# オレンジ       0  100     0    0.0
# リンゴ        0  100     0  100.0
# ピーマン       0  100     0    0.0

# %% [markdown]
# # 3.4 model3　グローバルプーリングを用いたCNN
#
# 従来、畳込みニューラルネットワークは出力層側に数層の全結合層を設けるのが一般的でしたが、全結合はパラメータ数が膨大になります。たとえば、モデル２は約64万パラメータですが、そのうち50万以上は全結合層のパラメータであり、学習時間のほとんどはその部分の調整に費やされていることになります。
#
# 最近、全結合層をグローバルプーリング層（GlobalAveragePooling2D）に置き換えたネットワークの利用が流行っています。
#
# 普通のプーリングは、畳み込みニューラルネットワークにおいて、１チャネル中の２ｘ２＝４つのデータをその平均値や最大値に集約する処理を言いますが、グローバルプーリングは大胆にも１チャネル全体の平均を取って、１チャネルをたった１データに集約する処理です。
#
# たとえばモデル２では、全結合層の直前でサイズ(8x8)のチャネルが64チャネル、計4096のノードがありますが、グローバルプーリングではそれを各チャネル１ノード、計64ノードに集約します。
#
# 結果として、そこから出力までの間のパラメータ数は64分の１に減ります。
#
# 問題は、それがパフォーマンスにどう影響するかです。
#
# ということで、実際に試してみましょう。

# %%
# Model 3
NN3 = Sequential([
    Conv2D(64, kernel_size=(3, 3),input_shape=(SIZE, SIZE,3), activation='relu',padding='same'),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    BatchNormalization(),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    Conv2D(64, kernel_size=(3, 3), activation='relu',padding='same'),
    MaxPool2D(pool_size=(2, 2)),
    #BatchNormalization(),
    GlobalAveragePooling2D(),
    Dense(CLASSES, activation='softmax')])

# CATLIST=[cat1,cat2,cat3] # カテゴリのリスト　（3カテゴリ限定）
# DSET = (Xtrain,ytrain,Xtest,ytest) # データセット
model3 = NNModel(model=NN3,catlist=CATLIST,dset=DSET,type='CNN') # 学習モデルのインスタンス生成
model3.summary() # モデルの概要表示
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        1792
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 64)        36928
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 113,027
# Trainable params: 112,899
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# |モデル|パラメータ数|
# |:--:|:--:|
# |model2|645,955|
# |model3|113,027|
#
# パラメータ数の違いが顕著です。

# %%
# 学習
model3.learn(verbose=1,epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 16ms/step - loss: 1.0918 - accuracy: 0.4100
# Epoch 2/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9831 - accuracy: 0.5767
# Epoch 3/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9033 - accuracy: 0.6233
# Epoch 4/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8557 - accuracy: 0.6367
# Epoch 5/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.8368 - accuracy: 0.6633
# Epoch 6/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7871 - accuracy: 0.6767
# Epoch 7/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7477 - accuracy: 0.7067
# Epoch 8/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7212 - accuracy: 0.6733
# Epoch 9/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7036 - accuracy: 0.6833
# Epoch 10/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6718 - accuracy: 0.7233
# Epoch 11/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6472 - accuracy: 0.7367
# Epoch 12/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6279 - accuracy: 0.7433
# Epoch 13/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6137 - accuracy: 0.7433
# Epoch 14/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6044 - accuracy: 0.7467
# Epoch 15/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5951 - accuracy: 0.7633
# Epoch 16/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5819 - accuracy: 0.7567
# Epoch 17/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5501 - accuracy: 0.7900
# Epoch 18/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5488 - accuracy: 0.7800
# Epoch 19/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5336 - accuracy: 0.7900
# Epoch 20/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5393 - accuracy: 0.7800
# Epoch 21/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5311 - accuracy: 0.8000
# Epoch 22/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5304 - accuracy: 0.7800
# Epoch 23/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5069 - accuracy: 0.7867
# Epoch 24/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4948 - accuracy: 0.8133
# Epoch 25/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4861 - accuracy: 0.8000
# Epoch 26/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4862 - accuracy: 0.8000
# Epoch 27/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4771 - accuracy: 0.8067
# Epoch 28/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4888 - accuracy: 0.8067
# Epoch 29/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4667 - accuracy: 0.8367
# Epoch 30/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4710 - accuracy: 0.8067
# Epoch 31/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4585 - accuracy: 0.8267
# Epoch 32/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4618 - accuracy: 0.8233
# Epoch 33/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4460 - accuracy: 0.8467
# Epoch 34/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4460 - accuracy: 0.8133
# Epoch 35/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4435 - accuracy: 0.8300
# Epoch 36/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4452 - accuracy: 0.8367
# Epoch 37/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4481 - accuracy: 0.8500
# Epoch 38/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4425 - accuracy: 0.8267
# Epoch 39/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4272 - accuracy: 0.8233
# Epoch 40/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4516 - accuracy: 0.8400
# Epoch 41/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4141 - accuracy: 0.8267
# Epoch 42/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4148 - accuracy: 0.8200
# Epoch 43/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3886 - accuracy: 0.8600
# Epoch 44/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4186 - accuracy: 0.8400
# Epoch 45/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4022 - accuracy: 0.8433
# Epoch 46/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3784 - accuracy: 0.8400
# Epoch 47/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4022 - accuracy: 0.8567
# Epoch 48/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3852 - accuracy: 0.8667
# Epoch 49/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3937 - accuracy: 0.8533
# Epoch 50/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3882 - accuracy: 0.8367
# Epoch 51/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3782 - accuracy: 0.8500
# Epoch 52/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3724 - accuracy: 0.8533
# Epoch 53/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3535 - accuracy: 0.8600
# Epoch 54/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3546 - accuracy: 0.8633
# Epoch 55/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3747 - accuracy: 0.8667
# Epoch 56/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3806 - accuracy: 0.8567
# Epoch 57/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3486 - accuracy: 0.8700
# Epoch 58/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3469 - accuracy: 0.8600
# Epoch 59/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3515 - accuracy: 0.8633
# Epoch 60/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3356 - accuracy: 0.8700
# Epoch 61/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3351 - accuracy: 0.8667
# Epoch 62/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3756 - accuracy: 0.8600
# Epoch 63/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3372 - accuracy: 0.8800
# Epoch 64/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3430 - accuracy: 0.8800
# Epoch 65/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3283 - accuracy: 0.8633
# Epoch 66/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3245 - accuracy: 0.8833
# Epoch 67/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3216 - accuracy: 0.8733
# Epoch 68/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3024 - accuracy: 0.8833
# Epoch 69/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3049 - accuracy: 0.8867
# Epoch 70/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3039 - accuracy: 0.8900
# Epoch 71/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3040 - accuracy: 0.8800
# Epoch 72/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3010 - accuracy: 0.8833
# Epoch 73/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3158 - accuracy: 0.8833
# Epoch 74/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2993 - accuracy: 0.8800
# Epoch 75/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2834 - accuracy: 0.8900
# Epoch 76/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3137 - accuracy: 0.8667
# Epoch 77/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2941 - accuracy: 0.8700
# Epoch 78/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2837 - accuracy: 0.9033
# Epoch 79/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2852 - accuracy: 0.8833
# Epoch 80/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2955 - accuracy: 0.8800

# %%
model3.hplot()

# %%
model3.recognitionResult()
# Out:
# 訓練データの認識率
# 誤認識 24/300
# 　正答率= 92.0　誤り率＝  8.0 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン   正答率
# 正解カテゴリ
# オレンジ      93    2     5  93.0
# リンゴ        0   91     9  91.0
# ピーマン       3    5    92  92.0
# テストデータの認識率
# 誤認識 72/300
# 　正答率= 76.0　誤り率＝ 24.0 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン   正答率
# 正解カテゴリ
# オレンジ      83   10     7  83.0
# リンゴ        5   75    20  75.0
# ピーマン      13   17    70  70.0

# %% [markdown]
# model2 と model3 を比較してみましょう。
#
# ただし、学習結果は乱数に左右されるので、同じカテゴリであっても常に同じ結果になるわけではありません。**１度の実験だけで、どちらがよい、と断言してはいけません**。モデル定義に戻って何度か実験を繰り返してから結論を出すようにしてください。
#
# モデル２とモデル３の誤答例を示しておきます。

# %%
# テストデータで間違った画像の例（モデル２）
model2.showErrorImages(mode = 'test')
# Out:
# 下に示す例を含め 200 枚

# %%
# テストデータで間違った画像の例（モデル３）
model3.showErrorImages(mode = 'test')
# Out:
# 下に示す例を含め 72 枚

# %% [markdown]
# # 3.5 model4 転移学習
#
# コンテストで上位に入ったモデルなどの学習済みデータがネット上に公開されています。
#
# その一部を自分のモデルに組み込み、それをもとに学習させることを**転移学習**と言います。
#
# 極端な話、リンゴ、オレンジ、ピーマンを含む１００種の野菜や果物を１００％識別可能な学習済みモデルがあるとしたら、それをもとにして学習を行えば、リンゴ、オレンジ、ピーマンの３カテゴリを１００％識別するのは容易でしょう。（ほぼチートです）
#
# ここでは、**MobileNetV2** という、モバイル端末向けの学習済みモデルをベースにして独自モデルを作ってみることにします。

# %% [markdown]
# # MobileNetV2 概観
#
# まず、MobileNetV2 がどんな構造なのか見ておきます。

# %%
# MobileNetV2 の出力部分を除いたモデル定義を再利用し、重みは、最後の部分以外はImagenet用の学習済み重みを転用する
mnv2 = keras.applications.MobileNetV2(input_shape=(96,96,3),
                                               include_top=False, 
                                               weights='imagenet')
# MobileNetV2 流用部分の構造確認
mnv2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# Model: "mobilenetv2_1.00_96"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  Conv1 (Conv2D)                 (None, 48, 48, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 48, 48, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 48, 48, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 48, 48, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 48, 48, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 48, 48, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 48, 48, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 48, 48, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 48, 48, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 48, 48, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 48, 48, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 49, 49, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 24, 24, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 24, 24, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 24, 24, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 24, 24, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 24, 24, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 24, 24, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 24, 24, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 24, 24, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 24, 24, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 25, 25, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 12, 12, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 12, 12, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 12, 12, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 12, 12, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 12, 12, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 12, 12, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 12, 12, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 12, 12, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 12, 12, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 12, 12, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 12, 12, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 13, 13, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 6, 6, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 6, 6, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 6, 6, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 6, 6, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 6, 6, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 6, 6, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 6, 6, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 6, 6, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 6, 6, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 6, 6, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 6, 6, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 6, 6, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 6, 6, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 6, 6, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 6, 6, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 6, 6, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 6, 6, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 6, 6, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 6, 6, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 6, 6, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 6, 6, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 6, 6, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 6, 6, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 6, 6, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 6, 6, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 6, 6, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 6, 6, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 6, 6, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 6, 6, 576)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 7, 7, 576)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 3, 3, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 3, 3, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 3, 3, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 3, 3, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 3, 3, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 3, 3, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 3, 3, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 3, 3, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 3, 3, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 3, 3, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 3, 3, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 3, 3, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 3, 3, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 3, 3, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 3, 3, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 3, 3, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %% [markdown]
# **include_top=False**とすると、全結合層がカットされた部分が得られます。Trueにするとわかりますが、実際には、このあとにGlobalPooling層があって、最後に1,000出力の出力層があります。
#
# 私達のネットワークは３出力なので、このネットワークの最後に、GlobalPooling層と３ノードの出力層を追加したものを、**model4** として定義します。

# %%
NN4 = Sequential([
    mnv2,
    GlobalAveragePooling2D(),
    Dense(CLASSES, activation='softmax')
])

# CATLIST=[cat1,cat2,cat3] # カテゴリのリスト　（3カテゴリ限定）
# DSET = (Xtrain,ytrain,Xtest,ytest) # データセット
model4 = NNModel(model=NN4,catlist=CATLIST,dset=DSET,type='CNN±1',reshape=(96,96)) # 学習モデルのインスタンス生成
model4.summary() # モデルの概要表示
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_96 (Functi  (None, 3, 3, 1280)       2257984
#  onal)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 2,261,827
# Trainable params: 2,227,715
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
# 学習
model4.learn(verbose=1,epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 7s 142ms/step - loss: 0.9325 - accuracy: 0.5900
# Epoch 2/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2218 - accuracy: 0.9433
# Epoch 3/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0801 - accuracy: 0.9933
# Epoch 4/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0561 - accuracy: 0.9933
# Epoch 5/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0289 - accuracy: 0.9967
# Epoch 6/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 7/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 8/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 9/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 10/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0136 - accuracy: 0.9967
# Epoch 11/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0235 - accuracy: 0.9933
# Epoch 12/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 13/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 14/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 15/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 16/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0079 - accuracy: 0.9967
# Epoch 17/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0115 - accuracy: 0.9967
# Epoch 18/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 20/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 23/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0114 - accuracy: 0.9933
# Epoch 24/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0174 - accuracy: 0.9933

# %%
# 学習過程のグラフ化
model4.hplot()

# %%
model4.recognitionResult()
# Out:
# 訓練データの認識率
# 誤認識 94/300
# 　正答率= 68.7　誤り率＝ 31.3 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン    正答率
# 正解カテゴリ
# オレンジ     100    0     0  100.0
# リンゴ       36   64     0   64.0
# ピーマン      42   16    42   42.0
# テストデータの認識率
# 誤認識 109/300
# 　正答率= 63.7　誤り率＝ 36.3 %
#
# カテゴリごとの認識結果と正答率
#         オレンジ  リンゴ  ピーマン    正答率
# 正解カテゴリ
# オレンジ     100    0     0  100.0
# リンゴ       41   57     2   57.0
# ピーマン      56   10    34   34.0

# %%
model4.showErrorImages(mode = 'train')
# Out:
# 下に示す例を含め 94 枚

# %%
model4.showErrorImages(mode = 'test')
# Out:
# 下に示す例を含め 109 枚

# %% [markdown]
# # <font color='red'>課題</font>
#
#
# * 例以外の３つのカテゴリで同じ実験を行い、結果をまとめて報告する。（複製を作って実行するとよい）
# * カテゴリは適当に３つ選ぶのではなく、なんらかの意図をもって、結果が予想できるような組み合わせにすること。レポートにその組み合わせを選んだ理由を述べること。
# * 結果についての考察を述べること。（感想は不要）
#
# 課題については、別に添付されている資料も参照すること。

# %% [markdown]
# # （付録）その他の利用可能な学習済みモデル
#
# Keras ライブラリで簡単に読み込み可能な学習済みモデル
#
# |Model|サイズ|1位の精度|Top-5 精度|パラメータ数|層数|
# |:--:|---:|:--:|:--:|---:|---:|
# |Xception|88 MB|0.790|0.945|22,910480|126|
# |VGG16|528 MB|0.715|0.901|138,357,544|23|
# |VGG19|549 MB|0.727|0.910|143,667,240|26|
# |ResNet50|99 MB|0.759|0.929|25,636,712|168|
# |InceptionV3|92 MB|0.788|0.944|23,851,784|159|
# |InceptionResNetV2|215 MB|0.804|0.953|55,873,736|572|
# |MobileNet|17 MB|0.665|0.871|4,253,864|88|
# |DenseNet121|33 MB|0.745|0.918|8,062,504|121|
# |DenseNet169|57 MB|0.759|0.928|14,307,880|169|
# |DenseNet201|80 MB|0.770|0.933|20,242,984|201|
#
# - https://keras.io/ja/applications/
#
# -CPUのみで計算する場合、計算時間はパラメータ数に比例すると考えればよい。
# -GPUが使えれば数分の１の時間で学習が済むので、まず、ランタイムメニューでランタイムのタイプをGPUにセットして試せばよい。GPUが使えればラッキー
#
# 参考までに、CPUの場合、VGG16での学習は30分以上かかったが、テストデータでの精度は77％程度となった。Xceptionの場合は80％程度の精度が得られる。（チューリップ、バラ、ヒマワリの場合の結果）
#
# ## 他の学習済みモデルの試し方
#
# ```
# # MobileNetV2 の出力部分を除いたモデル定義を再利用し、重みは、最後の部分以外はImagenet用の学習済み重みを転用する
# mnv2 = keras.applications.MobileNetV2(input_shape=(96,96,3),
#                                                include_top=False,
#                                                weights='imagenet')
# ```
#
# という部分を、**Xception** ならば、
#
# ```
# mnv2= keras.applications.Xception(input_shape=(96,96,3),
#                                                include_top=False,
#                                                weights='imagenet')
# ```
#
# **VGG16** ならば、
#
# ```
# mnv2 = keras.applications.VGG16(input_shape=(64,64,3),
#                                                include_top=False,
#                                                weights='imagenet')
# ```
# 等と書き換えればいいです。
